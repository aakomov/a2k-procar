# %%
import pandas as pd
import os

# %%
# Данные в виде списка словарей
data = [
    {"Car_Name": "ritz", "Year": 2014, "Selling_Price": 3.35, "Present_Price": 5.59, "Kms_Driven": 27000, "Fuel_Type": "Petrol", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 11, "Kms_Per_Year": 2250.000000},
    {"Car_Name": "sx4", "Year": 2013, "Selling_Price": 4.75, "Present_Price": 9.54, "Kms_Driven": 43000, "Fuel_Type": "Diesel", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 12, "Kms_Per_Year": 3307.692308},
    {"Car_Name": "ciaz", "Year": 2017, "Selling_Price": 7.25, "Present_Price": 9.85, "Kms_Driven": 6900, "Fuel_Type": "Petrol", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 8, "Kms_Per_Year": 766.666667},
    {"Car_Name": "wagon r", "Year": 2011, "Selling_Price": 2.85, "Present_Price": 4.15, "Kms_Driven": 5200, "Fuel_Type": "Petrol", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 14, "Kms_Per_Year": 346.666667},
    {"Car_Name": "swift", "Year": 2014, "Selling_Price": 4.60, "Present_Price": 6.87, "Kms_Driven": 42450, "Fuel_Type": "Diesel", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 11, "Kms_Per_Year": 3537.500000},
    {"Car_Name": "vitara brezza", "Year": 2018, "Selling_Price": 9.25, "Present_Price": 9.83, "Kms_Driven": 2071, "Fuel_Type": "Diesel", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 7, "Kms_Per_Year": 258.875000},
    {"Car_Name": "ciaz", "Year": 2015, "Selling_Price": 6.75, "Present_Price": 8.12, "Kms_Driven": 18796, "Fuel_Type": "Petrol", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 10, "Kms_Per_Year": 1708.727273},
    {"Car_Name": "s cross", "Year": 2015, "Selling_Price": 6.50, "Present_Price": 8.61, "Kms_Driven": 33429, "Fuel_Type": "Diesel", "Seller_Type": "Dealer", "Transmission": "Manual", "Owner": 0, "Car_Age": 10, "Kms_Per_Year": 3039.000000},
]

# %%
# Превращаем в DataFrame
df = pd.DataFrame(data)

# Убедимся, что путь существует
os.makedirs("../data/output_data", exist_ok=True)

# Сохраняем в parquet
df.to_parquet("../data/output_data/car_data_cleaned.parquet", index=False)

print("✅ Файл успешно сохранён:", "../data/output_data/car_data_cleaned.parquet")
df.head()
# Out:
# ✅ Файл успешно сохранён: ../data/output_data/car_data_cleaned.parquet
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age  Kms_Per_Year
# 0      Dealer       Manual      0       11   2250.000000
# 1      Dealer       Manual      0       12   3307.692308
# 2      Dealer       Manual      0        8    766.666667
# 3      Dealer       Manual      0       14    346.666667
# 4      Dealer       Manual      0       11   3537.500000
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
# ...
